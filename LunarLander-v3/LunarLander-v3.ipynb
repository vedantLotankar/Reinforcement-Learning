# %% [markdown]
# ## LunarLander-v3

# %%
import gymnasium as gym
from stable_baselines3 import DQN
import numpy as np

# %%
env = gym.make('LunarLander-v3', render_mode = 'human')

# %%
obs, _ = env.reset()
print("Initial Observation:", obs)
# Out:
# Initial Observation: [ 1.0460854e-03  1.4058739e+00  1.0592941e-01 -2.2427277e-01
#  -1.2052468e-03 -2.3994628e-02  0.0000000e+00  0.0000000e+00]

# %%
# Create the DQN model for LunarLander-v3
model = DQN("MlpPolicy", env, verbose=1, learning_rate=1e-3, buffer_size=50000, exploration_fraction=0.1, exploration_final_eps=0.02)

# Train the model
model.learn(total_timesteps=100000)

# Save the trained model
model.save("dqn_lunar_lander_v3")

print("Training completed successfully!")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | -123     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 46       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 391      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.81     |
# |    n_updates        | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -138     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 47       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 707      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.38     |
# |    n_updates        | 151      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 47       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1117     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.69     |
# |    n_updates        | 254      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 47       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1538     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.923    |
# |    n_updates        | 359      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 47       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 1943     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.779    |
# |    n_updates        | 460      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 47       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2384     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.446    |
# |    n_updates        | 570      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 47       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 2903     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.294    |
# |    n_updates        | 700      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 47       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 3444     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.39     |
# |    n_updates        | 835      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 47       |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 4090     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.12     |
# |    n_updates        | 997      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 47       |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 4640     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.2      |
# |    n_updates        | 1134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 47       |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 5497     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.407    |
# |    n_updates        | 1349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 47       |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 6815     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.372    |
# |    n_updates        | 1678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.149    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 48       |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 8679     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.946    |
# |    n_updates        | 2144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.0532   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 48       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 9661     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.992    |
# |    n_updates        | 2390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 48       |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 11007    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.746    |
# |    n_updates        | 2726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 48       |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 12127    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.72     |
# |    n_updates        | 3006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 48       |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 13792    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.52     |
# |    n_updates        | 3422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 48       |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 16002    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.88     |
# |    n_updates        | 3975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 48       |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 17614    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.43     |
# |    n_updates        | 4378     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 254      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 48       |
# |    time_elapsed     | 421      |
# |    total_timesteps  | 20336    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.831    |
# |    n_updates        | 5058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 267      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 48       |
# |    time_elapsed     | 465      |
# |    total_timesteps  | 22438    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.544    |
# |    n_updates        | 5584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 48       |
# |    time_elapsed     | 503      |
# |    total_timesteps  | 24269    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.725    |
# |    n_updates        | 6042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 48       |
# |    time_elapsed     | 559      |
# |    total_timesteps  | 27027    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.808    |
# |    n_updates        | 6731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 310      |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 48       |
# |    time_elapsed     | 615      |
# |    total_timesteps  | 29736    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.721    |
# |    n_updates        | 7408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 312      |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 48       |
# |    time_elapsed     | 645      |
# |    total_timesteps  | 31150    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.01     |
# |    n_updates        | 7762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 324      |
# |    ep_rew_mean      | -149     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 48       |
# |    time_elapsed     | 678      |
# |    total_timesteps  | 32760    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.98     |
# |    n_updates        | 8164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 48       |
# |    time_elapsed     | 711      |
# |    total_timesteps  | 34356    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.429    |
# |    n_updates        | 8563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | -149     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 48       |
# |    time_elapsed     | 753      |
# |    total_timesteps  | 36377    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.12     |
# |    n_updates        | 9069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 365      |
# |    ep_rew_mean      | -142     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 48       |
# |    time_elapsed     | 788      |
# |    total_timesteps  | 38078    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.58     |
# |    n_updates        | 9494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 48       |
# |    time_elapsed     | 823      |
# |    total_timesteps  | 39770    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.576    |
# |    n_updates        | 9917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 396      |
# |    ep_rew_mean      | -125     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 48       |
# |    time_elapsed     | 869      |
# |    total_timesteps  | 42016    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.982    |
# |    n_updates        | 10478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 48       |
# |    time_elapsed     | 948      |
# |    total_timesteps  | 45755    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.04     |
# |    n_updates        | 11413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 48       |
# |    time_elapsed     | 1005     |
# |    total_timesteps  | 48539    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.34     |
# |    n_updates        | 12109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 476      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 48       |
# |    time_elapsed     | 1071     |
# |    total_timesteps  | 51711    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.16     |
# |    n_updates        | 12902    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 504      |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 48       |
# |    time_elapsed     | 1140     |
# |    total_timesteps  | 55052    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.434    |
# |    n_updates        | 13737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 522      |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 48       |
# |    time_elapsed     | 1194     |
# |    total_timesteps  | 57665    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.514    |
# |    n_updates        | 14391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 544      |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 48       |
# |    time_elapsed     | 1268     |
# |    total_timesteps  | 61219    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.405    |
# |    n_updates        | 15279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 559      |
# |    ep_rew_mean      | -97.5    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 48       |
# |    time_elapsed     | 1337     |
# |    total_timesteps  | 64590    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.97     |
# |    n_updates        | 16122    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 576      |
# |    ep_rew_mean      | -77.1    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 48       |
# |    time_elapsed     | 1393     |
# |    total_timesteps  | 67257    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.696    |
# |    n_updates        | 16789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 591      |
# |    ep_rew_mean      | -70.3    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 48       |
# |    time_elapsed     | 1451     |
# |    total_timesteps  | 70083    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.16     |
# |    n_updates        | 17495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 620      |
# |    ep_rew_mean      | -68.8    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 48       |
# |    time_elapsed     | 1534     |
# |    total_timesteps  | 74083    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.385    |
# |    n_updates        | 18495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 643      |
# |    ep_rew_mean      | -72.8    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 48       |
# |    time_elapsed     | 1616     |
# |    total_timesteps  | 78083    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.22     |
# |    n_updates        | 19495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 661      |
# |    ep_rew_mean      | -73.2    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 48       |
# |    time_elapsed     | 1699     |
# |    total_timesteps  | 82083    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.321    |
# |    n_updates        | 20495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 683      |
# |    ep_rew_mean      | -68.1    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 48       |
# |    time_elapsed     | 1779     |
# |    total_timesteps  | 85960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.859    |
# |    n_updates        | 21464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 696      |
# |    ep_rew_mean      | -69.5    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 48       |
# |    time_elapsed     | 1862     |
# |    total_timesteps  | 89960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.776    |
# |    n_updates        | 22464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 715      |
# |    ep_rew_mean      | -67.2    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 48       |
# |    time_elapsed     | 1944     |
# |    total_timesteps  | 93960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.535    |
# |    n_updates        | 23464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 737      |
# |    ep_rew_mean      | -68.2    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 48       |
# |    time_elapsed     | 2027     |
# |    total_timesteps  | 97960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.455    |
# |    n_updates        | 24464    |
# ----------------------------------
# Training completed successfully!
